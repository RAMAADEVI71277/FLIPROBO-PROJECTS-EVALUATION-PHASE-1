# %% [markdown]
# # Evaluation Project - 1
#
# Baseball Case Study
#
# Problem Statement:
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# -- Output: Number of predicted wins (W)

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import warnings

# %% [markdown]
# # GETTING THE DATASET

# %%
df=pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# # EDA

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# # CHECKING AND REMOVING DUPLICATES

# %%
df['W'].duplicated().sum()
# Out:
# 6

# %%
df['R'].duplicated().sum()
# Out:
# 2

# %%
df['AB'].duplicated().sum()
# Out:
# 1

# %%
df['H'].duplicated().sum()
# Out:
# 1

# %%
df['2B'].duplicated().sum()
# Out:
# 8

# %%
df['3B'].duplicated().sum()
# Out:
# 7

# %%
df['HR'].duplicated().sum()
# Out:
# 3

# %%
df['BB'].duplicated().sum()
# Out:
# 1

# %%
df['SO'].duplicated().sum()
# Out:
# 1

# %%
df['SB'].duplicated().sum()
# Out:
# 3

# %%
df['RA'].duplicated().sum()
# Out:
# 0

# %%
df['ER'].duplicated().sum()
# Out:
# 0

# %%
df['ERA'].duplicated().sum()
# Out:
# 0

# %%
df['CG'].duplicated().sum()
# Out:
# 21

# %%
df['SHO'].duplicated().sum()
# Out:
# 18

# %%
df['SV'].duplicated().sum()
# Out:
# 10

# %%
df['E'].duplicated().sum()
# Out:
# 9

# %%
df.drop_duplicates()
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# # CHECKING AND CHANGING DTYPES INTO THE SAME

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
for i in df.columns:
    if df[i].dtypes=='float':
        df[i]=df[i].astype(int)

# %%
df.dtypes
# Out:
# W      int64
# R      int64
# AB     int64
# H      int64
# 2B     int64
# 3B     int64
# HR     int64
# BB     int64
# SO     int64
# SB     int64
# RA     int64
# ER     int64
# ERA    int32
# CG     int64
# SHO    int64
# SV     int64
# E      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# # DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df.plot(kind='box',subplots=True,layout=(3,7))
# Out:
# W         AxesSubplot(0.125,0.657941;0.0945122x0.222059)
# R      AxesSubplot(0.238415,0.657941;0.0945122x0.222059)
# AB     AxesSubplot(0.351829,0.657941;0.0945122x0.222059)
# H      AxesSubplot(0.465244,0.657941;0.0945122x0.222059)
# 2B     AxesSubplot(0.578659,0.657941;0.0945122x0.222059)
# 3B     AxesSubplot(0.692073,0.657941;0.0945122x0.222059)
# HR     AxesSubplot(0.805488,0.657941;0.0945122x0.222059)
# BB        AxesSubplot(0.125,0.391471;0.0945122x0.222059)
# SO     AxesSubplot(0.238415,0.391471;0.0945122x0.222059)
# SB     AxesSubplot(0.351829,0.391471;0.0945122x0.222059)
# RA     AxesSubplot(0.465244,0.391471;0.0945122x0.222059)
# ER     AxesSubplot(0.578659,0.391471;0.0945122x0.222059)
# ERA    AxesSubplot(0.692073,0.391471;0.0945122x0.222059)
# CG     AxesSubplot(0.805488,0.391471;0.0945122x0.222059)
# SHO          AxesSubplot(0.125,0.125;0.0945122x0.222059)
# SV        AxesSubplot(0.238415,0.125;0.0945122x0.222059)
# ...

# %% [markdown]
# FROM THE ABOVE WE FIND OUTLIERS IN ONLY FEW VARIABLES WHICH CAN BE REMOVED.

# %%
sns.histplot(data=df,x='W',y='R')
# Out:
# <AxesSubplot:xlabel='W', ylabel='R'>

# %% [markdown]
# FROM THE ABOVE WE FIND THAT MORE WINS (W) ARE WITH MORE THAN 600 RUNS AND WITHIN 725

# %%
sns.catplot(data=df,x='AB',kind='violin')

# %% [markdown]
# THE ABOVE SHOWS THE DISTRIBUTION OF SCORES DURING ATBATS

# %%
sns.boxplot(data=df,x='2B',y='3B')
# Out:
# <AxesSubplot:xlabel='2B', ylabel='3B'>

# %% [markdown]
# THE ABOVE SHOWS THE DIFFERENCE BETWEEN DOUBLES AND TRIPLES

# %%
plt.bar(df['HR'],df['BB'])
# Out:
# <BarContainer object of 30 artists>

# %% [markdown]
# THE ABOVE SHOWS COMPARISON BETWEEN HOMERUNS AND WALKS

# %%
sns.jointplot(data=df,x='CG',y='E')

# %% [markdown]
# THE ABOVE SHOWS THE JOINTPLOT OF COMPLETE GAMES AND ERRORS

# %% [markdown]
# # DATA CLEANSING

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# MEAN AND MEDIAN OF HITS,HOMERUNS,BB,CG AND E SHOWS DIFFERENCE AND RIGHTLY SKEWED
# MANY VARIABLES LIKE HR,BB,SB SHOWS DIFFERENCE BETWEEN 75% AND MAX ,SO THERE ARE OUTLIERS PRESENT

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.iloc[:,0:].boxplot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # OUTLIERS PRESENT WHICH CAN BE REMOVED

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA   -0.133406
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# # REMOVING OUTLIERS

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
dfnew=df[(z<3).all(axis=1)]

# %%
dfnew.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA   -0.207387
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
dfnew.shape
# Out:
# (29, 17)

# %%
dfnew.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER  ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601    3   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653    4   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584    3  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643    3   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746    4   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # SPLITTING INPUT VARIABLE(X) AND OUTPUT VARIABLE (Y)

# %%
x=dfnew.iloc[:,1:]
y=dfnew['W']

# %%
x.shape
# Out:
# (29, 16)

# %%
y.shape
# Out:
# (29,)

# %% [markdown]
# # TRAINING AND TESTING

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
maxR2=0
maxRS=0
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr.fit(x_train,y_train)
    predlr=lr.predict(x_test)
    score=r2_score(y_test,predlr)
    print('R2_score of Linear Regression ', score, 'at random_state' ,i)
    if score >maxR2:
        maxR2=score
        maxRS=i
    print('Max r2_score of lr is ' ,maxR2 * 100, 'at random state ' ,maxRS)
# Out:
# R2_score of Linear Regression  0.1335660393855106 at random_state 0
# Max r2_score of lr is  13.356603938551059 at random state  0
# R2_score of Linear Regression  0.8105261610470906 at random_state 1
# Max r2_score of lr is  81.05261610470906 at random state  1
# R2_score of Linear Regression  -0.5938429745960432 at random_state 2
# Max r2_score of lr is  81.05261610470906 at random state  1
# R2_score of Linear Regression  0.8280158030560785 at random_state 3
# Max r2_score of lr is  82.80158030560784 at random state  3
# R2_score of Linear Regression  0.555168864137036 at random_state 4
# Max r2_score of lr is  82.80158030560784 at random state  3
# R2_score of Linear Regression  0.4296776293651273 at random_state 5
# Max r2_score of lr is  82.80158030560784 at random state  3
# R2_score of Linear Regression  0.8736546541412293 at random_state 6
# Max r2_score of lr is  87.36546541412294 at random state  6
# R2_score of Linear Regression  0.18661880206498793 at random_state 7
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=303)
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
score=r2_score(y_test,predlr)
print('Best r2_score of LinearRegression ', score *100 ,'at random_state 168')
print(mean_squared_error(y_test,predlr))
print(mean_absolute_error(y_test,predlr))
# Out:
# Best r2_score of LinearRegression  92.66851513280375 at random_state 168
# 8.651152143291588
# 2.3799851319504435

# %% [markdown]
# # TRYING WITH VARIOUS REGRESSION MODELS

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor,RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
knr=KNeighborsRegressor()
gbr=GradientBoostingRegressor()
abr=AdaBoostRegressor()
etr=ExtraTreesRegressor()
rfr=RandomForestRegressor()
dtr=DecisionTreeRegressor()
svr=SVR()

# %%
model=[knr,gbr,abr,etr,rfr,dtr,svr]
for i in model:
    i.fit(x_train,y_train)
    predi=i.predict(x_test)
    print('R2_score of model ' , i ,'is = ',r2_score(y_test,predi)*100)
# Out:
# R2_score of model  KNeighborsRegressor() is =  3.621468926553706
# R2_score of model  GradientBoostingRegressor() is =  55.397755117636
# R2_score of model  AdaBoostRegressor() is =  44.12566698053987
# R2_score of model  ExtraTreesRegressor() is =  42.19831920903954
# R2_score of model  RandomForestRegressor() is =  46.93618644067797
# R2_score of model  DecisionTreeRegressor() is =  31.779661016949156
# R2_score of model  SVR() is =  -14.065381954844058

# %% [markdown]
# # CROSS_VALIDATION

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in range(2,10):
    models=[lr,knr,gbr,abr,etr,rfr,dtr,svr]
    for j in models:
        j.fit(x_train,y_train)
        predj=j.predict(x_test)
        score=r2_score(y_test,predj)
        cross=cross_val_score(j,x_train,y_train,cv=i)
        print('R2_score of model ' ,j, 'is equal = ', score*100)
        print('Cross validation of model ',i, 'is equal = ',cross.mean())
        print('Diff between r2_score and cross_validation of model ' ,j,'is equal = ',score-cross.mean())
# Out:
# R2_score of model  LinearRegression() is equal =  92.66851513280375
# Cross validation of model  2 is equal =  -4.442126667954863
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  5.3688118192829
# R2_score of model  KNeighborsRegressor() is equal =  3.621468926553706
# Cross validation of model  2 is equal =  0.3290311695482129
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  -0.2928164802826758
# R2_score of model  GradientBoostingRegressor() is equal =  55.59543951131716
# Cross validation of model  2 is equal =  0.4624360653374528
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  0.09351832977571878
# R2_score of model  AdaBoostRegressor() is equal =  35.91943885735922
# Cross validation of model  2 is equal =  0.4408577764889581
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  -0.08166338791536587
# ...

# %% [markdown]
# COMPARED TO ALL MODELS LINEAR REGRESSION WORKS BEST , SO WE WILL REGULARISE IT

# %% [markdown]
# # REGULARISATION

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet
l=Lasso()
r=Ridge()
en=ElasticNet()

# %%
models=[l,r,en]
for i in models:
    i.fit(x_train,y_train)
    alpha=[0.001,0.001,0.01,0.1,1]
    for j in alpha:
        predmodel=i.predict(x_test)
        print('R2_score : ' ,(r2_score(y_test,predmodel))*100, 'at model ',i,'with alpha ',j)
        print(mean_squared_error(y_test,predmodel))
        print(mean_absolute_error(y_test,predmodel))
# Out:
# R2_score :  77.85064893504594 at model  Lasso() with alpha  0.001
# 26.136234256645793
# 4.207228237325377
# R2_score :  77.85064893504594 at model  Lasso() with alpha  0.001
# 26.136234256645793
# 4.207228237325377
# R2_score :  77.85064893504594 at model  Lasso() with alpha  0.01
# 26.136234256645793
# 4.207228237325377
# R2_score :  77.85064893504594 at model  Lasso() with alpha  0.1
# 26.136234256645793
# 4.207228237325377
# R2_score :  77.85064893504594 at model  Lasso() with alpha  1
# 26.136234256645793
# 4.207228237325377
# R2_score :  92.7504832553122 at model  Ridge() with alpha  0.001
# 8.554429758731589
# 2.5640327248324675
# R2_score :  92.7504832553122 at model  Ridge() with alpha  0.001
# 8.554429758731589
# 2.5640327248324675
# R2_score :  92.7504832553122 at model  Ridge() with alpha  0.01
# 8.554429758731589
# 2.5640327248324675
# R2_score :  92.7504832553122 at model  Ridge() with alpha  0.1
# 8.554429758731589
# 2.5640327248324675
# ...

# %% [markdown]
# # FROM ABOVE WE FOUND RIDGE() AS THE BEST FITTED MODEL

# %% [markdown]
# # SAVING THE BEST FITTED MODEL

# %%
import pickle

# %%
filename='Baseball_Case_Study.pkl'
pickle.dump(Ridge(),open(filename,'wb'))

# %% [markdown]
# # LOADED THE BEST SAVED MODEL

# %%
pickle.load(open(filename,'rb'))
# Out:
# Ridge()
